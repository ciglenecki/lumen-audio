# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import librosa
import re
import os
import warnings
import matplotlib as mpl

from tqdm import tqdm

warnings.filterwarnings("ignore")

# %%
# %cd ../..
# Out:
# /home/irep/Desktop/lumen-audio

# %%
def read_all_names_train(split="train"):
    all_instr = os.listdir(f"./data/irmas/{split}")
    all_dirs = [
        f"./data/irmas/{split}/{i}" for i in all_instr if os.path.isdir(f"./data/irmas/{split}/{i}")
    ]
    all_files = []
    for d, instr in zip(all_dirs, all_instr):
        all_files.extend([f"./data/irmas/{split}/{instr}/{j}" for j in os.listdir(d)])
    return all_files

def find_all_features(train_names):
    instruments, drums, genre = [], [], []
    for name in train_names:
        match = re.findall("\[([^]]+)\]", name)
        if "nod" not in match and "dru" not in match:
            match.insert(1, None)
        if len(match) != 3:
            match.remove("---")
        instruments.append(match[0])
        drums.append(match[1])
        genre.append(match[2])
    return instruments, drums, genre

all_train_files = read_all_names_train("train")
instruments, drums, genre = find_all_features(all_train_files)

df_train = pd.DataFrame.from_dict({
    "path":all_train_files,
    "predominant_instrument":instruments,
    "drums":drums,
    "genres":genre
})

df_train.head()
# Out:
#                                                 path predominant_instrument
# 0  ./data/irmas/train/gel/071__[gel][dru][cou_fol...                    gel  \
# 1   ./data/irmas/train/gel/[gel][pop_roc]1034__3.wav                    gel
# 2   ./data/irmas/train/gel/[gel][pop_roc]0898__3.wav                    gel
# 3  ./data/irmas/train/gel/194__[gel][dru][cou_fol...                    gel
# 4  ./data/irmas/train/gel/081__[gel][dru][pop_roc...                    gel
#
#   drums   genres
# 0   dru  cou_fol
# 1  None  pop_roc
# 2  None  pop_roc
# 3   dru  cou_fol
# 4   dru  pop_roc

# %%
def read_all_names_test():
    all_txt = sorted([i for i in os.listdir("data/irmas/test") if i.endswith(".txt")])
    all_wav = sorted([i for i in os.listdir("data/irmas/test") if i.endswith(".wav")])
    instruments, names = [], []
    for i, j in zip(all_wav, all_txt):
        labels = [k.strip() for k in open(f"./data/irmas/test/{j}").read().split("\n") if k.strip() != ""]
        name = i
        instruments.append(labels)
        names.append(f"./data/irmas/test/{name}")
    return instruments, names
        
def count_num_songs():
    all_wavs = sorted([i for i in os.listdir("data/irmas/test") if i.endswith(".wav")])
    song_names = set(["-".join(i.split("-")[:-1]) for i in all_wavs])
    print("number of songs:", len(song_names))
    
count_num_songs()
instruments, names = read_all_names_test()

df_test = pd.DataFrame.from_dict({
    "instruments": instruments,
    "path":names
})
pattern = re.compile(r'^(.*?)-(\d{1,2})\.wav$')
df_test[['song_name', 'song_number']] = df_test['path'].str.extract(pattern)
song_groups = df_test.groupby('song_name')
song_id = 1
for name, group in song_groups:
    df_test.loc[group.index, 'song_id'] = song_id
    song_id += 1
df_test['song_id'] = df_test['song_id'].astype(int)
df_test['song_number'] = df_test['song_number'].astype(int)
df_test = df_test.sort_values(['song_id', 'song_number'], ascending=[True, True])

df_test.head(30)
# Out:
# number of songs: 208
#         instruments                                               path
# 0             [gel]   ./data/irmas/test/(02) dont kill the whale-1.wav  \
# 6        [gel, voi]   ./data/irmas/test/(02) dont kill the whale-2.wav
# 7        [gel, voi]   ./data/irmas/test/(02) dont kill the whale-3.wav
# 8             [gel]   ./data/irmas/test/(02) dont kill the whale-4.wav
# 9        [gel, voi]   ./data/irmas/test/(02) dont kill the whale-6.wav
# 10            [gel]   ./data/irmas/test/(02) dont kill the whale-8.wav
# 11       [gel, pia]   ./data/irmas/test/(02) dont kill the whale-9.wav
# 1             [gel]  ./data/irmas/test/(02) dont kill the whale-11.wav
# 2        [gel, voi]  ./data/irmas/test/(02) dont kill the whale-12.wav
# 3        [gel, voi]  ./data/irmas/test/(02) dont kill the whale-13.wav
# 4        [gel, voi]  ./data/irmas/test/(02) dont kill the whale-14.wav
# 5        [gel, pia]  ./data/irmas/test/(02) dont kill the whale-15.wav
# 12            [voi]           ./data/irmas/test/00 - gold fronts-1.wav
# 16       [gel, voi]           ./data/irmas/test/00 - gold fronts-2.wav
# 17       [gel, voi]           ./data/irmas/test/00 - gold fronts-3.wav
# 18       [gel, voi]           ./data/irmas/test/00 - gold fronts-4.wav
# 19       [gel, voi]           ./data/irmas/test/00 - gold fronts-5.wav
# 20       [gel, voi]           ./data/irmas/test/00 - gold fronts-7.wav
# 21       [gel, voi]           ./data/irmas/test/00 - gold fronts-8.wav
# 13            [gel]          ./data/irmas/test/00 - gold fronts-10.wav
# 14       [pia, voi]          ./data/irmas/test/00 - gold fronts-12.wav
# 15       [gac, voi]          ./data/irmas/test/00 - gold fronts-13.wav
# 22            [voi]       ./data/irmas/test/00 - yazoo - dont go-3.wav
# 23            [voi]       ./data/irmas/test/00 - yazoo - dont go-4.wav
# 24            [voi]       ./data/irmas/test/00 - yazoo - dont go-5.wav
# 25            [voi]       ./data/irmas/test/00 - yazoo - dont go-8.wav
# 26            [voi]       ./data/irmas/test/00 - yazoo - dont go-9.wav
# 27       [gac, org]  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE-...
# 36  [gac, org, voi]  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE-...
# 37  [gac, org, voi]  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE-...
#
#                                         song_name  song_number  song_id
# 0      ./data/irmas/test/(02) dont kill the whale            1        1
# 6      ./data/irmas/test/(02) dont kill the whale            2        1
# 7      ./data/irmas/test/(02) dont kill the whale            3        1
# 8      ./data/irmas/test/(02) dont kill the whale            4        1
# 9      ./data/irmas/test/(02) dont kill the whale            6        1
# 10     ./data/irmas/test/(02) dont kill the whale            8        1
# 11     ./data/irmas/test/(02) dont kill the whale            9        1
# 1      ./data/irmas/test/(02) dont kill the whale           11        1
# 2      ./data/irmas/test/(02) dont kill the whale           12        1
# 3      ./data/irmas/test/(02) dont kill the whale           13        1
# 4      ./data/irmas/test/(02) dont kill the whale           14        1
# 5      ./data/irmas/test/(02) dont kill the whale           15        1
# 12             ./data/irmas/test/00 - gold fronts            1        2
# 16             ./data/irmas/test/00 - gold fronts            2        2
# 17             ./data/irmas/test/00 - gold fronts            3        2
# 18             ./data/irmas/test/00 - gold fronts            4        2
# 19             ./data/irmas/test/00 - gold fronts            5        2
# 20             ./data/irmas/test/00 - gold fronts            7        2
# 21             ./data/irmas/test/00 - gold fronts            8        2
# 13             ./data/irmas/test/00 - gold fronts           10        2
# 14             ./data/irmas/test/00 - gold fronts           12        2
# 15             ./data/irmas/test/00 - gold fronts           13        2
# 22         ./data/irmas/test/00 - yazoo - dont go            3        3
# 23         ./data/irmas/test/00 - yazoo - dont go            4        3
# 24         ./data/irmas/test/00 - yazoo - dont go            5        3
# 25         ./data/irmas/test/00 - yazoo - dont go            8        3
# 26         ./data/irmas/test/00 - yazoo - dont go            9        3
# 27  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE            1        4
# 36  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE            3        4
# 37  ./data/irmas/test/0050_10CC___I_M_NOT_IN_LOVE            4        4

# %%
def instruments_compared_to_genre():
    plt.bar("")
